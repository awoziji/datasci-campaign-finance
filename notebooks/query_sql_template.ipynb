# %% [markdown]
# # SQL Querying

# %% [markdown]
# This notebook can be used to query tables in the Congressional Data database. In order to use this notebook, you will need to set an environment variable 'CD_DWH' to the database connection string. If you do not have the credentials, please slack us at #datasci-congressdata channel and/or talk to a project lead.
#
# **It is best practice to not hard code database URI strings directly in notebooks or code as when we push to Github, that would mean credentials are public for anyone to see.**

# %%
import os
import sys

import pandas as pd
pd.options.display.max_columns = 999
import sqlalchemy as sqla
from sqlalchemy import create_engine

DB_URI = os.getenv('CD_DWH')
engine = create_engine(DB_URI)

# %%
# Checking that the Kernel is using the Conda environment datasci-congressional-data
# Below you should see something like '/Users/Username/anaconda3/envs/datasci-congressional-data/bin/python
# If you do NOT see "datasci-congressional-data" this means you are not in the right Python Environment
# Please make sure you have gone through the onboarding docs and/or talk to a project lead.
sys.executable
# Out:
# '/Users/VincentLa/anaconda3/envs/datasci-congressional-data/bin/python'

# %% [markdown]
# Below are the tables that currently exist in the database!

# %%
QUERY = """
select *
from information_schema.tables
where table_schema not in ('information_schema', 'pg_catalog', 'public')
"""
with engine.begin() as conn:
    results = pd.read_sql(QUERY, conn)
results.head(100)
# Out:
#               table_catalog   table_schema  \
# 0  datascicongressionaldata  stg_analytics
# 1  datascicongressionaldata  stg_analytics
# 2  datascicongressionaldata  trg_analytics
# 3  datascicongressionaldata    data_ingest
# 4  datascicongressionaldata    data_ingest
# 5  datascicongressionaldata    data_ingest
# 6  datascicongressionaldata    fuzzy_merge
# 7  datascicongressionaldata    data_ingest
# 8  datascicongressionaldata    data_ingest
#
#                                           table_name  table_type  \
# 0                        stg_candidate_contributions  BASE TABLE
# 1                     stg_candidate_election_results  BASE TABLE
# 2                            candidate_contributions  BASE TABLE
# 3                     maplight__california_candidate  BASE TABLE
# 4                         maplight__california_other  BASE TABLE
# 5  casos__california_candidate_statewide_election...  BASE TABLE
# 6                                all_candidate_names  BASE TABLE
# 7  ceda__california_candidate_local_election_results  BASE TABLE
# 8         sfdata__campaign_finance_form460_schedulea  BASE TABLE
#
#   self_referencing_column_name reference_generation user_defined_type_catalog  \
# 0                         None                 None                      None
# 1                         None                 None                      None
# 2                         None                 None                      None
# 3                         None                 None                      None
# 4                         None                 None                      None
# 5                         None                 None                      None
# 6                         None                 None                      None
# 7                         None                 None                      None
# 8                         None                 None                      None
#
#   user_defined_type_schema user_defined_type_name is_insertable_into is_typed  \
# 0                     None                   None                YES       NO
# 1                     None                   None                YES       NO
# 2                     None                   None                YES       NO
# 3                     None                   None                YES       NO
# 4                     None                   None                YES       NO
# 5                     None                   None                YES       NO
# 6                     None                   None                YES       NO
# 7                     None                   None                YES       NO
# 8                     None                   None                YES       NO
#
#   commit_action
# 0          None
# 1          None
# 2          None
# 3          None
# 4          None
# 5          None
# 6          None
# 7          None
# 8          None

# %% [markdown]
# ## Query Example

# %%
QUERY = """
select
  *
from trg_analytics.candidate_contributions
limit 10
"""
with engine.begin() as conn:
    results = pd.read_sql(QUERY, conn)
results.head(100)
# Out:
#    transaction_id       transaction_type election_cycle    election  \
# 0  773097 - A2344  Monetary Contribution           2001  2002-11-05
# 1  773097 - A2383  Monetary Contribution           2001  2002-11-05
# 2  773097 - A2229  Monetary Contribution           2001  2002-11-05
# 3  773097 - A2313  Monetary Contribution           2001  2002-11-05
# 4  773097 - A2256  Monetary Contribution           2001  2002-11-05
# 5  773097 - A2257  Monetary Contribution           2001  2002-11-05
# 6  773097 - A2318  Monetary Contribution           2001  2002-11-05
# 7  773097 - A2219  Monetary Contribution           2001  2002-11-05
# 8  773097 - A2260  Monetary Contribution           2001  2002-11-05
# 9  773097 - A2325  Monetary Contribution           2001  2002-11-05
#
#    primary_general_indicator transaction_date  transaction_amount  filed_date  \
# 0                          0       2001-06-25               100.0  2001-07-31
# 1                          0       2001-06-15               250.0  2001-07-31
# 2                          0       2001-06-17               100.0  2001-07-31
# 3                          0       2001-06-17               100.0  2001-07-31
# 4                          0       2001-06-17               200.0  2001-07-31
# 5                          0       2001-06-15               200.0  2001-07-31
# 6                          0       2001-06-29              3000.0  2001-07-31
# 7                          0       2001-06-18              1000.0  2001-07-31
# 8                          0       2001-06-18                50.0  2001-07-31
# 9                          0       2001-06-15               250.0  2001-07-31
#
#       recipient_committee_name recipient_candidate_name  \
# 0  Mark Leno for Assembly 2002               LENO, MARK
# 1  Mark Leno for Assembly 2002               LENO, MARK
# 2  Mark Leno for Assembly 2002               LENO, MARK
# 3  Mark Leno for Assembly 2002               LENO, MARK
# 4  Mark Leno for Assembly 2002               LENO, MARK
# 5  Mark Leno for Assembly 2002               LENO, MARK
# 6  Mark Leno for Assembly 2002               LENO, MARK
# 7  Mark Leno for Assembly 2002               LENO, MARK
# 8  Mark Leno for Assembly 2002               LENO, MARK
# 9  Mark Leno for Assembly 2002               LENO, MARK
#
#   recipient_candidate_party recipient_candidate_ico  \
# 0   NOT CURRENTLY SUPPORTED                    None
# 1   NOT CURRENTLY SUPPORTED                    None
# 2   NOT CURRENTLY SUPPORTED                    None
# 3   NOT CURRENTLY SUPPORTED                    None
# 4   NOT CURRENTLY SUPPORTED                    None
# 5   NOT CURRENTLY SUPPORTED                    None
# 6   NOT CURRENTLY SUPPORTED                    None
# 7   NOT CURRENTLY SUPPORTED                    None
# 8   NOT CURRENTLY SUPPORTED                    None
# 9   NOT CURRENTLY SUPPORTED                    None
#
#   recipient_candidate_status recipient_candidate_office  \
# 0    NOT CURRENTLY SUPPORTED             State Assembly
# 1    NOT CURRENTLY SUPPORTED             State Assembly
# 2    NOT CURRENTLY SUPPORTED             State Assembly
# 3    NOT CURRENTLY SUPPORTED             State Assembly
# 4    NOT CURRENTLY SUPPORTED             State Assembly
# 5    NOT CURRENTLY SUPPORTED             State Assembly
# 6    NOT CURRENTLY SUPPORTED             State Assembly
# 7    NOT CURRENTLY SUPPORTED             State Assembly
# 8    NOT CURRENTLY SUPPORTED             State Assembly
# 9    NOT CURRENTLY SUPPORTED             State Assembly
#
#   recipient_candidate_district              donor_name     donor_city  \
# 0                          13           Cohen, Paul J.    Mill Valley
# 1                          13           Cohen, Phillip     Boca Raton
# 2                          13       Cole, Josephine C.  San Francisco
# 3                          13       Abrams, Donald Ira  San Francisco
# 4                          13        Adelman, Marcy R.  San Francisco
# 5                          13        Adelman, Marcy R.  San Francisco
# 6                          13   Conwest Resources Inc.  San Francisco
# 7                          13      Cronander, Bruce L.  San Francisco
# 8                          13         Damiani, Anna B.  San Francisco
# 9                          13      Hiatt, Constance M.  San Francisco
#
#   donor_state donor_zip_code            donor_employer  \
# 0          CA          94941                      None
# 1          FL          33496                      None
# 2          CA          94114                      None
# 3          CA     94131-2001                      UCSF
# 4          CA          94107                      Self
# 5          CA          94107                      Self
# 6          CA          94107                      None
# 7          CA          94114                      None
# 8          CA          94114       State of California
# 9          CA     94114-3510  Hanson Bridgett & Marcus
#
#           donor_occupation donor_organization donor_industry  \
# 0  NOT CURRENTLY SUPPORTED                IND              0
# 1  NOT CURRENTLY SUPPORTED                IND              0
# 2  NOT CURRENTLY SUPPORTED                IND              0
# 3  NOT CURRENTLY SUPPORTED                IND              0
# 4  NOT CURRENTLY SUPPORTED                IND              0
# 5  NOT CURRENTLY SUPPORTED                IND              0
# 6  NOT CURRENTLY SUPPORTED                OTH              0
# 7  NOT CURRENTLY SUPPORTED                IND              0
# 8  NOT CURRENTLY SUPPORTED                IND              0
# 9  NOT CURRENTLY SUPPORTED                IND              0
#
#          donor_entity_type       donor_committee_id     donor_committee_name  \
# 0  NOT CURRENTLY SUPPORTED  NOT CURRENTLY SUPPORTED  NOT CURRENTLY SUPPORTED
# 1  NOT CURRENTLY SUPPORTED  NOT CURRENTLY SUPPORTED  NOT CURRENTLY SUPPORTED
# 2  NOT CURRENTLY SUPPORTED  NOT CURRENTLY SUPPORTED  NOT CURRENTLY SUPPORTED
# 3  NOT CURRENTLY SUPPORTED  NOT CURRENTLY SUPPORTED  NOT CURRENTLY SUPPORTED
# 4  NOT CURRENTLY SUPPORTED  NOT CURRENTLY SUPPORTED  NOT CURRENTLY SUPPORTED
# 5  NOT CURRENTLY SUPPORTED  NOT CURRENTLY SUPPORTED  NOT CURRENTLY SUPPORTED
# 6  NOT CURRENTLY SUPPORTED  NOT CURRENTLY SUPPORTED  NOT CURRENTLY SUPPORTED
# 7  NOT CURRENTLY SUPPORTED  NOT CURRENTLY SUPPORTED  NOT CURRENTLY SUPPORTED
# 8  NOT CURRENTLY SUPPORTED  NOT CURRENTLY SUPPORTED  NOT CURRENTLY SUPPORTED
# 9  NOT CURRENTLY SUPPORTED  NOT CURRENTLY SUPPORTED  NOT CURRENTLY SUPPORTED
#
#   donor_committee_type donor_committee_party
# 0                 None                  None
# 1                 None                  None
# 2                 None                  None
# 3                 None                  None
# 4                 None                  None
# 5                 None                  None
# 6                 None                  None
# 7                 None                  None
# 8                 None                  None
# 9                 None                  None

# %%
QUERY = """
select
  *
from data_ingest.sfdata__campaign_finance_form460_schedulea
limit 10
"""
with engine.begin() as conn:
    results = pd.read_sql(QUERY, conn)
results.head()
# Out:
#   filer_id                                         filer_naml  report_num  \
# 0  1250905                                   Newsom for Mayor           0
# 1  1317554  San Francisco Police Officers Association Issu...           0
# 2  1222599          Re-Elect District 4 Supervisor Leland Yee           0
# 3  1317554  San Francisco Police Officers Association Issu...           0
# 4   990028                               Protect our Benefits           0
#
#   committee_type    rpt_date   from_date   thru_date  elect_date  \
# 0            CTL  11/26/2003  10/19/2003  11/22/2003  11/04/2003
# 1            RCP  01/27/2011  10/17/2010  12/31/2010        None
# 2            CTL  07/28/2000  01/01/2000  06/30/2000  11/07/2000
# 3            RCP  01/31/2012  10/23/2011  12/31/2011        None
# 4            RCP  07/25/2016  01/01/2016  06/30/2016        None
#
#   tblcover_office_cd tblcover_offic_dscr rec_type form_type   tran_id  \
# 0               None                None     RCPT         A    A15709
# 1               None                None     RCPT         A  INC44026
# 2               None                None     RCPT         A      A110
# 3               None                None     RCPT         A  INC99151
# 4               None                None     RCPT         A   INC3998
#
#   entity_cd                 tran_naml  tran_namf tran_namt tran_nams  \
# 0       OTH  R. Zaballos & Sons, Inc.       None      None      None
# 1       IND                       Yee    Gregory      None      None
# 2       IND                       Mah   Frank L.      None      None
# 3       IND                    Pagano       Rene      None      None
# 4       IND                     Serpa  Anthony J      None      None
#
#   tran_adr1 tran_adr2      tran_city tran_state tran_zip4  \
# 0      None      None        Hayward         CA     94541
# 1      None      None  San Francisco         CA     94103
# 2      None      None  San Francisco         CA     94122
# 3      None      None  San Francisco         CA     94103
# 4      None      None  Pleasant Hill         CA     94523
#
#                          tran_emp        tran_occ tran_self tran_type  \
# 0                            None            None         n      None
# 1  City & County of San Francisco  Police Officer         n      None
# 2                      Self-empl.      Consultant         n      None
# 3  City & County of San Francisco  Police Officer         n      None
# 4                            None         Retired         n      None
#
#     tran_date tran_date1 tran_amt1 tran_amt2 tran_dscr cmte_id tres_naml  \
# 0  11/19/2003       None   $250.00   $500.00      None    None      None
# 1  11/18/2010       None     $4.60   $163.37      None    None      None
# 2  06/13/2000       None   $100.00   $100.00      None    None      None
# 3  11/22/2011       None     $1.00   $119.66      None    None      None
# 4  02/09/2016       None   $200.00   $200.00      None    None      None
#
#   tres_namf tres_namt tres_nams tres_adr1 tres_adr2 tres_city tres_state  \
# 0      None      None      None      None      None      None       None
# 1      None      None      None      None      None      None       None
# 2      None      None      None      None      None      None       None
# 3      None      None      None      None      None      None       None
# 4      None      None      None      None      None      None       None
#
#   tres_zip intr_naml intr_namf intr_namt intr_nams intr_adr1 intr_adr2  \
# 0     None      None      None      None      None      None      None
# 1     None      None      None      None      None      None      None
# 2     None      None      None      None      None      None      None
# 3     None      None      None      None      None      None      None
# 4     None      None      None      None      None      None      None
#
#   intr_city intr_state intr_zip4 intr_emp intr_occ intr_self cand_naml  \
# 0      None       None      None     None     None         n      None
# 1      None       None      None     None     None         n      None
# 2      None       None      None     None     None         n      None
# 3      None       None      None     None     None         n      None
# 4      None       None      None     None     None         n      None
#
#   cand_namf cand_namt cand_nams tbldetltran_office_cd tbldetltran_offic_dscr  \
# 0      None      None      None                  None                   None
# 1      None      None      None                  None                   None
# 2      None      None      None                  None                   None
# 3      None      None      None                  None                   None
# 4      None      None      None                  None                   None
#
#   juris_cd juris_dscr dist_no off_s_h_cd bal_name bal_num bal_juris  \
# 0     None       None    None       None     None    None      None
# 1     None       None    None       None     None    None      None
# 2     None       None    None       None     None    None      None
# 3     None       None    None       None     None    None      None
# 4     None       None    None       None     None    None      None
#
#   sup_opp_cd memo_code memo_refno bakref_tid xref_schnm xref_match loan_rate  \
# 0       None      None       None       None       None       None      None
# 1       None      None       None       None       None       None      None
# 2       None      None       None       None       None       None      None
# 3       None      None       None       None       None       None      None
# 4       None      None       None       None       None       None      None
#
#   int_cmteid                    tran_location tres_location intr_location
# 0       None  94541\n(37.674148, -122.087822)          None          None
# 1       None  94103\n(37.772469, -122.411853)          None          None
# 2       None   94122\n(37.761208, -122.48469)          None          None
# 3       None  94103\n(37.772469, -122.411853)          None          None
# 4       None  94523\n(37.953455, -122.074721)          None          None

# %%
pd.to_datetime(results.rpt_date)
# Out:
# 0   2003-11-26
# 1   2011-01-27
# 2   2000-07-28
# 3   2012-01-31
# 4   2016-07-25
# 5   2005-11-01
# 6   2014-05-20
# 7   2000-07-28
# 8   2003-01-31
# 9   2002-10-04
# Name: rpt_date, dtype: datetime64[ns]

# %%
results.tran_amt1.replace('[\$,]', '', regex=True).astype(float)
# Out:
# 0    250.0
# 1      4.6
# 2    100.0
# 3      1.0
# 4    200.0
# 5    200.0
# 6    100.0
# 7    100.0
# 8    200.0
# 9    100.0
# Name: tran_amt1, dtype: float64

# %%
results.tran_amt1
# Out:
# 0    $250.00
# 1      $4.60
# 2    $100.00
# 3      $1.00
# 4    $200.00
# 5    $200.00
# 6    $100.00
# 7    $100.00
# 8    $200.00
# 9    $100.00
# Name: tran_amt1, dtype: object
